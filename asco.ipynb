# %%
import pandas as pd
df = pd.read_csv("dummy-actas.csv", header = 0)
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/5w/20rgdr855rj10fgd1szccrb00000gq/T/ipykernel_43848/2225160523.py", line 2, in <module>
#     df = pd.read_excel('dummy-actas.xlsx')
#
#   File "/usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.9/site-packages/pandas/io/excel/_base.py", line 364, in read_excel
#     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#
#   File "/usr/local/lib/python3.9/site-packages/pandas/io/excel/_base.py", line 1178, in __init__
#     if import_optional_dependency("xlrd", errors="ignore") is None:
#
#   File "/usr/local/lib/python3.9/site-packages/pandas/compat/_optional.py", line 115, in import_optional_dependency
# ...

# %%
df.head()
# Out:
#                  nombre_archivo  fecha_acta  \
# 0  Consejo Académico 297-22.pdf  2022-01-22
# 1  Consejo Académico 297-22.pdf  2022-01-22
# 2  Consejo Académico 297-22.pdf  2022-01-22
# 3  Consejo Académico 297-22.pdf  2022-01-22
# 4  Consejo Académico 297-22.pdf  2022-01-22
#
#                                           tag nivel                 actores  \
# 0             Oferta de cursos,Oferta virtual   NaN             Estudiantes
# 1  Estructura Interna,Cambios administrativos   NaN  Estudiantes,Profesores
# 2                              Representación   NaN  Estudiantes,Profesores
# 3                         Informe de gestión    NaN          Administración
# 4                          Creación Programas   NaN              Profesores
#
#       unidad                                           extracto
# 0        NaN  La rectora (e) anunció que la cartelera de cur...
# 1        NaN  La rectora (e) mencionó que, dadas las nuevas ...
# ...

# %%
palabra = "Informe"
df[df['tag'].str.contains("Informe")]
# Out:
#                   nombre_archivo  fecha_acta  \
# 3   Consejo Académico 297-22.pdf  2022-01-22
# 13  Consejo Académico 297-22.pdf  2022-01-22
# 32  Consejo Académico 297-22.pdf  2022-01-22
# 43  Consejo Académico 298-22.pdf  2022-02-03
#
#                                             tag              nivel  \
# 3                           Informe de gestión                 NaN
# 13                          Informe de gestión                 NaN
# 32  Admisión,Informe de gestión,Posicionamiento                NaN
# 43   Informe de gestión,Promoción investigación  Pregrado,Posgrado
#
#                    actores             unidad  \
# 3           Administración          Educación
# 13                     NaN          Educación
# 32             Estudiantes                NaN
# 43  Estudiantes,Profesores  Ciencias sociales
#
#                                              extracto
# 3   La rectora (e) informó que el Comité Directivo...
# ...
